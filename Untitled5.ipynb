# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
len(x_train)
len(x_test)
x_train[0].shape
plt.matshow(x_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-f8f352d6486c> in <cell line: 4>()
#       2 len(x_test)
#       3 x_train[0].shape
# ----> 4 plt.matshow(x_train)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in matshow(A, fignum, **kwargs)
#    2248         fig = figure(fignum, figsize=figaspect(A))
#    2249         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
# -> 2250     im = ax.matshow(A, **kwargs)
#    2251     sci(im)
#    2252     return im
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in matshow(self, Z, **kwargs)
#    7976               'aspect': 'equal',          # (already the imshow default)
#    7977               **kwargs}
# -> 7978         im = self.imshow(Z, **kw)
#    7979         self.title.set_y(1.05)
#    7980         self.xaxis.tick_top()
#
# ...

# %%
#to find size of the image
len(x_train)
len(x_test)
x_train[0].shape
# Out:
# (28, 28)

# %%
#normalizing
x_train = x_train/255
x_test = x_test/255

#flatting the dataset in order
#to compute for model building
x_train_flatten = x_train.reshape(len(x_train), 28*28)
x_test_flatten = x_test.reshape(len(x_test),28*28)

# %%
model = keras.Sequential([
  keras.layers.Dense(10, input_shape=(784,),  #10 nodes = 10 classes, 28*28 = 784
          activation='sigmoid')
])
model.compile(
    optimizer='adam' ,
    loss='sparse_categorical_crossentropy' ,
    metrics=['accuracy'])

model.fit(x_train_flatten, y_train, epochs=4) #epochs-used to determine accuracy
# Out:
# Epoch 1/4
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.1877 - accuracy: 0.5870
# Epoch 2/4
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.9768 - accuracy: 0.7101
# Epoch 3/4
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.7900 - accuracy: 0.7372
# Epoch 4/4
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.6261 - accuracy: 0.7601

# %%
#slct an img frm test data base
image_index = 5 #you can change this index to view different images

#display the selected image
plt.imshow(x_test[image_index], cmap='gray')
plt.show()

#perform prediction on slctd img
prediction = model.predict(x_test_flatten[image_index].reshape(1, 784))

#print the prediction label
predicted_label = np.argmax(prediction)
print(f"predicted label for the selected image:(predicted_label)")
# Out:
# 1/1 [==============================] - 0s 24ms/step
# predicted label for the selected image:(predicted_label)
